# %% [markdown]
# # Lecture 21: Lab3, Galaxies, & ML
#
# ### Nov 10, 2025

# %% [markdown]
# # Lab 3 Timeline
#
#   - PDF of the Lab is on [GitHub](https://github.com/ucb-datalab/course_materials_fa2025/blob/main/labs/AY128_Lab3_image_classification_fall2025.pdf).
#
#   - **Assigned**: Nov. 10, 2025
#   - **Checkpoints**: Nov. 19, 2025; Dec. 3, 2025
#   - Final Write Up (in LaTex) Due: Friday, Dec. 12, 2025 by 11:59pm

# %% [markdown]
# # Agenda
#
# - Introduction (this notebook, *00_Introduction*)
# - Lab 3 Overview
# - Galaxies Intro (*01_galaxies_intro*)
# - ML Intro (*02_intro_to_machine_learning*)
# - Lab 3 in more detail
# - Neural Nets? (*03_neural_networks*)
